# %% [markdown]
# ### Book Recommender

# %% [markdown]
# ## Imports

# %%
import time
import pandas as pd
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
# open file called .env and read in our API
file = open('./.env')
api = file.read()

# %% [markdown]
# ## Getting data from Good Reads API : 1-5000 iterations (users)
# > https://www.goodreads.com/api

# %%
# !pip install xmljson
# Out:
# Requirement already satisfied: xmljson in /anaconda3/lib/python3.7/site-packages (0.2.0)

# %%
from xmljson import badgerfish as bf
from xml.etree.ElementTree import fromstring
from json import dumps
import json

# %%
def get_data(user_count):
    dataset = {}
    complete_set = []
    for i in range(1, user_count+1):
        url = 'https://www.goodreads.com/review/list?v=2'
        key = api
        url_params = {
                        'key': key,
                        'id': i,
                        'per_page': 200
                    }
        response = requests.get(url, params=url_params)
        dataset[i] = json.loads(dumps(bf.data(fromstring(response.content))))

        try:
            for j in range(len(dataset[i]['GoodreadsResponse']['reviews']['review'])):
                    if dataset[i]['GoodreadsResponse']['reviews']['review'][j]['rating']['$'] > 0:
                        complete_set.append(dict([
                        ('User',i),
                        ('Book', dataset[i]['GoodreadsResponse']['reviews']['review'][j]['book']['title']['$']), 
                        ('Rating', dataset[i]['GoodreadsResponse']['reviews']['review'][j]['rating']['$'])]))
        except:
            pass
        time.sleep(1)
        
        #see where we're at
        if i % 50 == 0:
            print(i)
        
        if response.status_code != 200:
            print(i, response.status_code)
            
        
    df_one = pd.DataFrame(complete_set)
    df_one.to_csv('first_book_data')
    df_one = pd.read_csv('first_book_data')
    return df_one

# %%
start = time.time()
df_one = get_data(5000)
end = time.time()
print(end - start)
# Out:
# 11 404
# 14 403
# 17 404
# 19 403
# 30 403
# 32 403
# 36 403
# 39 404
# 41 403
# 42 403
# 46 403
# 48 404
# 50
# 54 403
# 60 404
# 67 403
# 75 403
# 77 403
# 78 403
# 79 404
# 80 403
# 81 404
# 82 404
# 83 403
# 85 404
# 98 403
# 100
# 102 404
# 112 403
# 115 404
# 120 403
# 130 404
# 133 403
# 135 403
# 142 403
# 150
# 152 403
# 154 404
# 162 404
# 164 403
# 174 404
# 176 403
# 189 404
# 199 403
# 200
# 200 404
# 201 403
# 211 404
# 212 403
# 220 404
# 221 404
# 226 403
# 229 403
# 232 403
# 233 404
# 240 404
# 246 403
# 250
# 254 404
# 256 403
# 258 404
# 261 403
# 265 403
# 272 403
# 277 403
# 283 404
# 289 403
# 293 404
# 298 403
# 300
# 310 404
# 324 403
# 325 403
# 330 404
# 336 403
# 350
# 361 404
# 367 404
# 371 403
# 375 404
# 380 404
# 389 403
# 395 404
# 400
# 407 403
# 411 403
# 422 404
# 424 404
# 431 404
# 445 403
# 449 403
# 450
# 450 403
# 453 404
# 473 404
# 478 403
# 500
# 508 404
# 514 404
# 518 404
# 525 404
# 550
# 555 404
# 559 404
# 564 404
# 577 403
# 586 403
# 591 404
# 593 404
# 600
# 602 403
# 613 403
# 614 403
# 615 404
# 618 403
# 623 403
# 624 404
# 626 404
# 627 404
# 650
# 654 404
# 659 404
# 662 404
# 663 404
# 668 404
# 677 403
# 686 404
# 687 404
# 688 404
# 695 404
# 700
# 708 404
# 715 403
# 750
# 752 404
# 763 404
# 765 404
# 792 403
# 794 404
# 800
# 801 404
# 803 404
# 824 404
# 826 403
# 827 403
# 834 404
# 850
# 852 404
# 853 403
# 864 404
# 874 403
# 875 403
# 895 403
# 900
# 901 404
# 906 404
# 907 404
# 919 403
# 922 403
# 928 403
