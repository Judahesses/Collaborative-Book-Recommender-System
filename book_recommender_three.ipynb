# %% [markdown]
# ### Book Recommender

# %% [markdown]
# ## Imports

# %%
import time
import pandas as pd
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
# open file called .env and read in our API
file = open('./.env')
api = file.read()

# %% [markdown]
# ## Getting data from Good Reads API : 10000 - 15000 iterations (users)
# > https://www.goodreads.com/api

# %%
# !pip install xmljson
# Out:
# Requirement already satisfied: xmljson in /anaconda3/lib/python3.7/site-packages (0.2.0)

# %%
from xmljson import badgerfish as bf
from xml.etree.ElementTree import fromstring
from json import dumps
import json

# %%
def get_data(user_count):
    dataset = {}
    complete_set = []
    for i in range(10000, user_count+1):
        url = 'https://www.goodreads.com/review/list?v=2'
        key = api
        url_params = {
                        'key': key,
                        'id': i,
                        'per_page': 200
                    }
        response = requests.get(url, params=url_params)
        dataset[i] = json.loads(dumps(bf.data(fromstring(response.content))))

        try:
            for j in range(len(dataset[i]['GoodreadsResponse']['reviews']['review'])):
                    if dataset[i]['GoodreadsResponse']['reviews']['review'][j]['rating']['$'] > 0:
                        complete_set.append(dict([
                        ('User',i),
                        ('Book', dataset[i]['GoodreadsResponse']['reviews']['review'][j]['book']['title']['$']), 
                        ('Rating', dataset[i]['GoodreadsResponse']['reviews']['review'][j]['rating']['$'])]))
        except:
            pass
        time.sleep(1)
        
        #see where we're at
        if i % 50 == 0:
            print(i)

        if response.status_code != 200:
            print(i, response.status_code)         
            
    df_three = pd.DataFrame(complete_set)
    df_three.to_csv('third_book_data')
    df_three = pd.read_csv('third_book_data')
    return df_three

# %%
start = time.time()
df_three = get_data(15000)
end = time.time()
print(end - start)
# Out:
# 10000
# 10050
# 10055 403
# 10089 403
# 10092 404
# 10097 404
# 10099 403
# 10100
# 10114 404
# 10117 404
# 10150
# 10181 404
# 10200
# 10200 404
# 10232 403
# 10250
# 10255 404
# 10268 403
# 10280 404
# 10285 404
# 10296 403
# 10300
# 10315 403
# 10341 404
# 10346 403
# 10350
# 10356 403
# 10364 403
# 10386 403
# 10387 404
# 10400
# 10416 403
# 10423 404
# 10424 404
# 10433 403
# 10442 403
# 10450
# 10455 403
# 10463 403
# 10466 404
# 10479 404
# 10489 404
# 10493 403
# 10500
# 10517 403
# 10542 404
# 10543 404
# 10547 403
# 10550
# 10551 403
# 10572 403
# 10577 403
# 10586 403
# 10587 404
# 10596 404
# 10600
# 10619 403
# 10640 403
# 10650
# 10658 404
# 10674 403
# 10675 403
# 10692 403
# 10700
# 10714 404
# 10715 403
# 10716 404
# 10744 404
# 10750
# 10751 404
# 10754 404
# 10761 404
# 10762 404
# 10775 404
# 10790 403
# 10800
# 10810 404
# 10816 403
# 10818 404
# 10821 404
# 10824 404
# 10825 404
# 10832 404
# 10834 404
# 10836 404
# 10850
# 10858 404
# 10859 404
# 10868 404
# 10900
# 10933 404
# 10950
# 10952 404
# 10983 404
# 11000
# 11035 403
# 11050
# 11100
# 11126 403
# 11144 403
